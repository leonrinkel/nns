# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from datetime import datetime
from maraboupy import Marabou

# %%
MODEL_PATH = "mnist_model"
TRAIN_EPOCHS = 3
NUM_SAMPLES_TO_TRY = 500
DELTA = 0.01
EPSILON = 0.1

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()
train_x = train_x.reshape((train_x.shape[0], 784)) / 255.0
test_x = test_x.reshape((test_x.shape[0], 784)) / 255.0
print("train data shape", train_x.shape, train_y.shape)
print("test data shape", test_x.shape, test_y.shape)
# Out:
# train data shape (60000, 784) (60000,)
# test data shape (10000, 784) (10000,)

# %%
tf_model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(784)),
    tf.keras.layers.Dense(16, activation=tf.keras.layers.ReLU()),
    tf.keras.layers.Dense(16, activation=tf.keras.layers.ReLU()),
    tf.keras.layers.Dense(10),
])

# %%
tf_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                12560
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf_model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
tf_model.fit(
    train_x, train_y,
    epochs=TRAIN_EPOCHS,
    validation_data=(test_x, test_y),
)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 2s 717us/step - loss: 0.7079 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.2725 - val_sparse_categorical_accuracy: 0.9195
# Epoch 2/3
# 1875/1875 [==============================] - 1s 460us/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.2294 - val_sparse_categorical_accuracy: 0.9331
# Epoch 3/3
# 1875/1875 [==============================] - 1s 455us/step - loss: 0.2235 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.2137 - val_sparse_categorical_accuracy: 0.9360

# %%
tf.saved_model.save(tf_model, MODEL_PATH)
# Out:
# WARNING:absl:Found untraced functions such as re_lu_layer_call_and_return_conditional_losses, re_lu_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses, re_lu_1_layer_call_fn, re_lu_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as re_lu_layer_call_and_return_conditional_losses, re_lu_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses, re_lu_1_layer_call_fn, re_lu_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: mnist_model\assets
# INFO:tensorflow:Assets written to: mnist_model\assets

# %%
adv_x = np.empty((0, 784), int)
adv_y = np.empty((0), int)
num_sat_samples = 0
num_unsat_samples = 0

# %%
print("start time", datetime.now().strftime("%H:%M:%S"))

samples_to_try = zip(train_x[:NUM_SAMPLES_TO_TRY], train_y[:NUM_SAMPLES_TO_TRY])
for sample_index, (image, actual_label) in enumerate(samples_to_try):
    
    for target_label in range(10):
        if target_label == actual_label: continue
        
        mb_model = Marabou.read_tf(MODEL_PATH, modelType="savedModel_v2")
        mb_input_vars = mb_model.inputVars[0][0]
        mb_output_vars = mb_model.outputVars[0]
        
        for variable, value in enumerate(image):
            mb_model.setLowerBound(mb_input_vars[variable], value - DELTA)
            mb_model.setUpperBound(mb_input_vars[variable], value + DELTA)

        for label in range(10):
            if label != target_label:
                mb_model.addInequality(
                    [ mb_output_vars[label], mb_output_vars[target_label] ],
                    [ +1.0, -1.0 ], -1.0 * EPSILON,
                )
        
        mb_variables, stats = mb_model.solve("marabou.log", verbose=False)
        if not mb_variables:
            num_unsat_samples += 1
            print(f"unsat for sample {sample_index} with target label {target_label}")
            continue
        num_sat_samples += 1
        print(f"sat for sample {sample_index} with target label {target_label}")
        
        image = list()
        for i in range(0, 784):
            image.append(mb_variables[mb_input_vars[i]])
        
        adv_x = np.append(adv_x, np.array([image]), axis=0)
        adv_y = np.append(adv_y, np.array([actual_label]), axis=0)
        
        np.save("adv_x.npy", adv_x)
        np.save("adv_y.npy", adv_y)
        
        print("adv data shape", adv_x.shape, adv_y.shape)
        print(f"num sat samples: {num_sat_samples}, " \
              f"num unsat samples: {num_unsat_samples}")

print("end time", datetime.now().strftime("%H:%M:%S"))
# Out:
# start time 12:14:14
# unsat for sample 0 with target label 0
# unsat for sample 0 with target label 1
# unsat for sample 0 with target label 2
# unsat for sample 0 with target label 3
# unsat for sample 0 with target label 4
# unsat for sample 0 with target label 6
# unsat for sample 0 with target label 7
# unsat for sample 0 with target label 8
# unsat for sample 0 with target label 9
# unsat for sample 1 with target label 1
# unsat for sample 1 with target label 2
# unsat for sample 1 with target label 3
# unsat for sample 1 with target label 4
# unsat for sample 1 with target label 5
# unsat for sample 1 with target label 6
# unsat for sample 1 with target label 7
# unsat for sample 1 with target label 8
# unsat for sample 1 with target label 9
# unsat for sample 2 with target label 0
# unsat for sample 2 with target label 1
# unsat for sample 2 with target label 2
# unsat for sample 2 with target label 3
# unsat for sample 2 with target label 5
# unsat for sample 2 with target label 6
# unsat for sample 2 with target label 7
# unsat for sample 2 with target label 8
# unsat for sample 2 with target label 9
# unsat for sample 3 with target label 0
# unsat for sample 3 with target label 2
# unsat for sample 3 with target label 3
# unsat for sample 3 with target label 4
# unsat for sample 3 with target label 5
# unsat for sample 3 with target label 6
# unsat for sample 3 with target label 7
# unsat for sample 3 with target label 8
# unsat for sample 3 with target label 9
# unsat for sample 4 with target label 0
# unsat for sample 4 with target label 1
# unsat for sample 4 with target label 2
# unsat for sample 4 with target label 3
# unsat for sample 4 with target label 4
# unsat for sample 4 with target label 5
# unsat for sample 4 with target label 6
# unsat for sample 4 with target label 7
# unsat for sample 4 with target label 8
# unsat for sample 5 with target label 0
# unsat for sample 5 with target label 1
# unsat for sample 5 with target label 3
# unsat for sample 5 with target label 4
# unsat for sample 5 with target label 5
# unsat for sample 5 with target label 6
# unsat for sample 5 with target label 7
# unsat for sample 5 with target label 8
# unsat for sample 5 with target label 9
# unsat for sample 6 with target label 0
# unsat for sample 6 with target label 2
# unsat for sample 6 with target label 3
# unsat for sample 6 with target label 4
# unsat for sample 6 with target label 5
# unsat for sample 6 with target label 6
# unsat for sample 6 with target label 7
# unsat for sample 6 with target label 8
# unsat for sample 6 with target label 9
# unsat for sample 7 with target label 0
# unsat for sample 7 with target label 1
# unsat for sample 7 with target label 2
# unsat for sample 7 with target label 4
# unsat for sample 7 with target label 5
# unsat for sample 7 with target label 6
# unsat for sample 7 with target label 7
# unsat for sample 7 with target label 8
# unsat for sample 7 with target label 9
# unsat for sample 8 with target label 0
# unsat for sample 8 with target label 2
# unsat for sample 8 with target label 3
# unsat for sample 8 with target label 4
# unsat for sample 8 with target label 5
# unsat for sample 8 with target label 6
# unsat for sample 8 with target label 7
# unsat for sample 8 with target label 8
# unsat for sample 8 with target label 9
# unsat for sample 9 with target label 0
# unsat for sample 9 with target label 1
# unsat for sample 9 with target label 2
# unsat for sample 9 with target label 3
# unsat for sample 9 with target label 5
# unsat for sample 9 with target label 6
# unsat for sample 9 with target label 7
# unsat for sample 9 with target label 8
# unsat for sample 9 with target label 9
# unsat for sample 10 with target label 0
# unsat for sample 10 with target label 1
# unsat for sample 10 with target label 2
# unsat for sample 10 with target label 4
# unsat for sample 10 with target label 5
# unsat for sample 10 with target label 6
# unsat for sample 10 with target label 7
# unsat for sample 10 with target label 8
# unsat for sample 10 with target label 9
# unsat for sample 11 with target label 0
# unsat for sample 11 with target label 1
# unsat for sample 11 with target label 2
# unsat for sample 11 with target label 3
# unsat for sample 11 with target label 4
# unsat for sample 11 with target label 6
# unsat for sample 11 with target label 7
# unsat for sample 11 with target label 8
# unsat for sample 11 with target label 9
# unsat for sample 12 with target label 0
# unsat for sample 12 with target label 1
# unsat for sample 12 with target label 2
# unsat for sample 12 with target label 4
# unsat for sample 12 with target label 5
# unsat for sample 12 with target label 6
# unsat for sample 12 with target label 7
# unsat for sample 12 with target label 8
# unsat for sample 12 with target label 9
# unsat for sample 13 with target label 0
# unsat for sample 13 with target label 1
# unsat for sample 13 with target label 2
# unsat for sample 13 with target label 3
# unsat for sample 13 with target label 4
# unsat for sample 13 with target label 5
# unsat for sample 13 with target label 7
# unsat for sample 13 with target label 8
# unsat for sample 13 with target label 9
# unsat for sample 14 with target label 0
# unsat for sample 14 with target label 2
# unsat for sample 14 with target label 3
# unsat for sample 14 with target label 4
# unsat for sample 14 with target label 5
# unsat for sample 14 with target label 6
# unsat for sample 14 with target label 7
# unsat for sample 14 with target label 8
# unsat for sample 14 with target label 9
# unsat for sample 15 with target label 0
# unsat for sample 15 with target label 1
# unsat for sample 15 with target label 2
# unsat for sample 15 with target label 3
# unsat for sample 15 with target label 4
# unsat for sample 15 with target label 5
# unsat for sample 15 with target label 6
# unsat for sample 15 with target label 8
# unsat for sample 15 with target label 9
# unsat for sample 16 with target label 0
# unsat for sample 16 with target label 1
# unsat for sample 16 with target label 3
# unsat for sample 16 with target label 4
# unsat for sample 16 with target label 5
# unsat for sample 16 with target label 6
# unsat for sample 16 with target label 7
# unsat for sample 16 with target label 8
# unsat for sample 16 with target label 9
# unsat for sample 17 with target label 0
# unsat for sample 17 with target label 1
# unsat for sample 17 with target label 2
# unsat for sample 17 with target label 3
# unsat for sample 17 with target label 4
# unsat for sample 17 with target label 5
# unsat for sample 17 with target label 6
# unsat for sample 17 with target label 7
# unsat for sample 17 with target label 9
# unsat for sample 18 with target label 0
# unsat for sample 18 with target label 1
# unsat for sample 18 with target label 2
# unsat for sample 18 with target label 3
# unsat for sample 18 with target label 4
# sat for sample 18 with target label 5
# adv data shape (1, 784) (1,)
# num sat samples: 1, num unsat samples: 167
# unsat for sample 18 with target label 7
# unsat for sample 18 with target label 8
# unsat for sample 18 with target label 9
# unsat for sample 19 with target label 0
# unsat for sample 19 with target label 1
# unsat for sample 19 with target label 2
# unsat for sample 19 with target label 3
# unsat for sample 19 with target label 4
# unsat for sample 19 with target label 5
# unsat for sample 19 with target label 6
# unsat for sample 19 with target label 7
# unsat for sample 19 with target label 8
# unsat for sample 20 with target label 0
# unsat for sample 20 with target label 1
# unsat for sample 20 with target label 2
# unsat for sample 20 with target label 3
# unsat for sample 20 with target label 5
# unsat for sample 20 with target label 6
# unsat for sample 20 with target label 7
# unsat for sample 20 with target label 8
# unsat for sample 20 with target label 9
# unsat for sample 21 with target label 1
# unsat for sample 21 with target label 2
# unsat for sample 21 with target label 3
# unsat for sample 21 with target label 4
# unsat for sample 21 with target label 5
# unsat for sample 21 with target label 6
# unsat for sample 21 with target label 7
# unsat for sample 21 with target label 8
# unsat for sample 21 with target label 9
# unsat for sample 22 with target label 0
# unsat for sample 22 with target label 1
# unsat for sample 22 with target label 2
# unsat for sample 22 with target label 3
# sat for sample 22 with target label 4
# adv data shape (2, 784) (2,)
# num sat samples: 2, num unsat samples: 201
# unsat for sample 22 with target label 5
# unsat for sample 22 with target label 6
# unsat for sample 22 with target label 7
# unsat for sample 22 with target label 8
# unsat for sample 23 with target label 0
# unsat for sample 23 with target label 2
# unsat for sample 23 with target label 3
# unsat for sample 23 with target label 4
# unsat for sample 23 with target label 5
# unsat for sample 23 with target label 6
# unsat for sample 23 with target label 7
# unsat for sample 23 with target label 8
# unsat for sample 23 with target label 9
# unsat for sample 24 with target label 0
# unsat for sample 24 with target label 2
# sat for sample 24 with target label 3
# adv data shape (3, 784) (3,)
# num sat samples: 3, num unsat samples: 216
# unsat for sample 24 with target label 4
# sat for sample 24 with target label 5
# adv data shape (4, 784) (4,)
# num sat samples: 4, num unsat samples: 217
# sat for sample 24 with target label 6
# adv data shape (5, 784) (5,)
# num sat samples: 5, num unsat samples: 217
# unsat for sample 24 with target label 7
# unsat for sample 24 with target label 8
# unsat for sample 24 with target label 9
# unsat for sample 25 with target label 0
# unsat for sample 25 with target label 1
# unsat for sample 25 with target label 3
# unsat for sample 25 with target label 4
# unsat for sample 25 with target label 5
# unsat for sample 25 with target label 6
# unsat for sample 25 with target label 7
# unsat for sample 25 with target label 8
# unsat for sample 25 with target label 9
# unsat for sample 26 with target label 0
# unsat for sample 26 with target label 1
# unsat for sample 26 with target label 2
# unsat for sample 26 with target label 3
# unsat for sample 26 with target label 5
# unsat for sample 26 with target label 6
# unsat for sample 26 with target label 7
# unsat for sample 26 with target label 8
# unsat for sample 26 with target label 9
# unsat for sample 27 with target label 0
# unsat for sample 27 with target label 1
# unsat for sample 27 with target label 2
# unsat for sample 27 with target label 4
# unsat for sample 27 with target label 5
# unsat for sample 27 with target label 6
# unsat for sample 27 with target label 7
# unsat for sample 27 with target label 8
# unsat for sample 27 with target label 9
# unsat for sample 28 with target label 0
# unsat for sample 28 with target label 1
# unsat for sample 28 with target label 3
# unsat for sample 28 with target label 4
# unsat for sample 28 with target label 5
# unsat for sample 28 with target label 6
# sat for sample 28 with target label 7
# adv data shape (6, 784) (6,)
# num sat samples: 6, num unsat samples: 253
# unsat for sample 28 with target label 8
# unsat for sample 28 with target label 9
# unsat for sample 29 with target label 0
# unsat for sample 29 with target label 1
# unsat for sample 29 with target label 2
# unsat for sample 29 with target label 3
# unsat for sample 29 with target label 4
# unsat for sample 29 with target label 5
# unsat for sample 29 with target label 6
# unsat for sample 29 with target label 8
# unsat for sample 29 with target label 9
# unsat for sample 30 with target label 0
# unsat for sample 30 with target label 1
# unsat for sample 30 with target label 2
# unsat for sample 30 with target label 4
# unsat for sample 30 with target label 5
# unsat for sample 30 with target label 6
# unsat for sample 30 with target label 7
# unsat for sample 30 with target label 8
# unsat for sample 30 with target label 9
# unsat for sample 31 with target label 0
# unsat for sample 31 with target label 1
# unsat for sample 31 with target label 2
# unsat for sample 31 with target label 3
# unsat for sample 31 with target label 4
# unsat for sample 31 with target label 5
# unsat for sample 31 with target label 6
# unsat for sample 31 with target label 7
# unsat for sample 31 with target label 9
# unsat for sample 32 with target label 0
# unsat for sample 32 with target label 1
# unsat for sample 32 with target label 2
# unsat for sample 32 with target label 3
# unsat for sample 32 with target label 4
# unsat for sample 32 with target label 5
# unsat for sample 32 with target label 7
# unsat for sample 32 with target label 8
# unsat for sample 32 with target label 9
# unsat for sample 33 with target label 0
# unsat for sample 33 with target label 1
# unsat for sample 33 with target label 2
# unsat for sample 33 with target label 3
# unsat for sample 33 with target label 4
# unsat for sample 33 with target label 5
# unsat for sample 33 with target label 6
# sat for sample 33 with target label 7
# adv data shape (7, 784) (7,)
# num sat samples: 7, num unsat samples: 298
# unsat for sample 33 with target label 8
# unsat for sample 34 with target label 1
# unsat for sample 34 with target label 2
# unsat for sample 34 with target label 3
# unsat for sample 34 with target label 4
# unsat for sample 34 with target label 5
# unsat for sample 34 with target label 6
# unsat for sample 34 with target label 7
# unsat for sample 34 with target label 8
# unsat for sample 34 with target label 9
# unsat for sample 35 with target label 0
# unsat for sample 35 with target label 1
# unsat for sample 35 with target label 2
# unsat for sample 35 with target label 3
# unsat for sample 35 with target label 4
# unsat for sample 35 with target label 6
# unsat for sample 35 with target label 7
# unsat for sample 35 with target label 8
# unsat for sample 35 with target label 9
# unsat for sample 36 with target label 0
# unsat for sample 36 with target label 1
# unsat for sample 36 with target label 2
# unsat for sample 36 with target label 3
# unsat for sample 36 with target label 4
# unsat for sample 36 with target label 5
# unsat for sample 36 with target label 7
# unsat for sample 36 with target label 8
# unsat for sample 36 with target label 9
# unsat for sample 37 with target label 1
# unsat for sample 37 with target label 2
# unsat for sample 37 with target label 3
# unsat for sample 37 with target label 4
# unsat for sample 37 with target label 5
# unsat for sample 37 with target label 6
# unsat for sample 37 with target label 7
# unsat for sample 37 with target label 8
# unsat for sample 37 with target label 9
# unsat for sample 38 with target label 0
# unsat for sample 38 with target label 1
# unsat for sample 38 with target label 2
# unsat for sample 38 with target label 3
# unsat for sample 38 with target label 4
# unsat for sample 38 with target label 5
# unsat for sample 38 with target label 6
# unsat for sample 38 with target label 8
# unsat for sample 38 with target label 9
# unsat for sample 39 with target label 0
# unsat for sample 39 with target label 1
# unsat for sample 39 with target label 2
# unsat for sample 39 with target label 3
# unsat for sample 39 with target label 4
# unsat for sample 39 with target label 5
# unsat for sample 39 with target label 7
# unsat for sample 39 with target label 8
# unsat for sample 39 with target label 9
# unsat for sample 40 with target label 0
# unsat for sample 40 with target label 2
# unsat for sample 40 with target label 3
# unsat for sample 40 with target label 4
# unsat for sample 40 with target label 5
# unsat for sample 40 with target label 6
# unsat for sample 40 with target label 7
# unsat for sample 40 with target label 8
# unsat for sample 40 with target label 9
# unsat for sample 41 with target label 0
# unsat for sample 41 with target label 1
# unsat for sample 41 with target label 2
# unsat for sample 41 with target label 3
# unsat for sample 41 with target label 4
# unsat for sample 41 with target label 5
# unsat for sample 41 with target label 6
# unsat for sample 41 with target label 7
# unsat for sample 41 with target label 9
# unsat for sample 42 with target label 0
# unsat for sample 42 with target label 1
# unsat for sample 42 with target label 2
# unsat for sample 42 with target label 3
# unsat for sample 42 with target label 4
# unsat for sample 42 with target label 5
# unsat for sample 42 with target label 6
# unsat for sample 42 with target label 8
# unsat for sample 42 with target label 9
# unsat for sample 43 with target label 0
# unsat for sample 43 with target label 1
# unsat for sample 43 with target label 2
# unsat for sample 43 with target label 3
# unsat for sample 43 with target label 4
# unsat for sample 43 with target label 5
# unsat for sample 43 with target label 6
# unsat for sample 43 with target label 7
# unsat for sample 43 with target label 8
# unsat for sample 44 with target label 0
# unsat for sample 44 with target label 1
# unsat for sample 44 with target label 2
# unsat for sample 44 with target label 4
# unsat for sample 44 with target label 5
# unsat for sample 44 with target label 6
# unsat for sample 44 with target label 7
# unsat for sample 44 with target label 8
# unsat for sample 44 with target label 9
# unsat for sample 45 with target label 0
# unsat for sample 45 with target label 1
# unsat for sample 45 with target label 2
# unsat for sample 45 with target label 3
# unsat for sample 45 with target label 4
# unsat for sample 45 with target label 5
# unsat for sample 45 with target label 6
# unsat for sample 45 with target label 7
# unsat for sample 45 with target label 8
# unsat for sample 46 with target label 0
# unsat for sample 46 with target label 1
# sat for sample 46 with target label 2
# adv data shape (8, 784) (8,)
# num sat samples: 8, num unsat samples: 409
# unsat for sample 46 with target label 3
# unsat for sample 46 with target label 4
# unsat for sample 46 with target label 5
# unsat for sample 46 with target label 6
# unsat for sample 46 with target label 7
# unsat for sample 46 with target label 9
# unsat for sample 47 with target label 0
# unsat for sample 47 with target label 1
# unsat for sample 47 with target label 2
# unsat for sample 47 with target label 3
# unsat for sample 47 with target label 4
# unsat for sample 47 with target label 6
# unsat for sample 47 with target label 7
# unsat for sample 47 with target label 8
# unsat for sample 47 with target label 9
# unsat for sample 48 with target label 0
# unsat for sample 48 with target label 1
# unsat for sample 48 with target label 2
# unsat for sample 48 with target label 3
# unsat for sample 48 with target label 4
# sat for sample 48 with target label 5
# adv data shape (9, 784) (9,)
# num sat samples: 9, num unsat samples: 429
# unsat for sample 48 with target label 6
# unsat for sample 48 with target label 7
# unsat for sample 48 with target label 8
# unsat for sample 49 with target label 0
# unsat for sample 49 with target label 1
# unsat for sample 49 with target label 2
# unsat for sample 49 with target label 4
# unsat for sample 49 with target label 5
# unsat for sample 49 with target label 6
# unsat for sample 49 with target label 7
# unsat for sample 49 with target label 8
# unsat for sample 49 with target label 9
# unsat for sample 50 with target label 0
# unsat for sample 50 with target label 1
# unsat for sample 50 with target label 2
# unsat for sample 50 with target label 4
# unsat for sample 50 with target label 5
# unsat for sample 50 with target label 6
# unsat for sample 50 with target label 7
# unsat for sample 50 with target label 8
# unsat for sample 50 with target label 9
# unsat for sample 51 with target label 1
# unsat for sample 51 with target label 2
# unsat for sample 51 with target label 3
# unsat for sample 51 with target label 4
# unsat for sample 51 with target label 5
# unsat for sample 51 with target label 6
# unsat for sample 51 with target label 7
# unsat for sample 51 with target label 8
# unsat for sample 51 with target label 9
# unsat for sample 52 with target label 0
# unsat for sample 52 with target label 1
# unsat for sample 52 with target label 2
# unsat for sample 52 with target label 3
# unsat for sample 52 with target label 4
# unsat for sample 52 with target label 5
# unsat for sample 52 with target label 6
# unsat for sample 52 with target label 8
# unsat for sample 52 with target label 9
# unsat for sample 53 with target label 0
# sat for sample 53 with target label 1
# adv data shape (10, 784) (10,)
# num sat samples: 10, num unsat samples: 469
# unsat for sample 53 with target label 2
# unsat for sample 53 with target label 3
# unsat for sample 53 with target label 5
# unsat for sample 53 with target label 6
# sat for sample 53 with target label 7
# adv data shape (11, 784) (11,)
# num sat samples: 11, num unsat samples: 473
# unsat for sample 53 with target label 8
# unsat for sample 53 with target label 9
# unsat for sample 54 with target label 0
# unsat for sample 54 with target label 1
# unsat for sample 54 with target label 2
# unsat for sample 54 with target label 3
# unsat for sample 54 with target label 4
# unsat for sample 54 with target label 5
# unsat for sample 54 with target label 6
# unsat for sample 54 with target label 7
# unsat for sample 54 with target label 8
# unsat for sample 55 with target label 0
# unsat for sample 55 with target label 1
# unsat for sample 55 with target label 2
# unsat for sample 55 with target label 3
# unsat for sample 55 with target label 4
# unsat for sample 55 with target label 5
# unsat for sample 55 with target label 6
# unsat for sample 55 with target label 7
# unsat for sample 55 with target label 9
# unsat for sample 56 with target label 1
# unsat for sample 56 with target label 2
# unsat for sample 56 with target label 3
# unsat for sample 56 with target label 4
# unsat for sample 56 with target label 5
# unsat for sample 56 with target label 6
# unsat for sample 56 with target label 7
# unsat for sample 56 with target label 8
# unsat for sample 56 with target label 9
# unsat for sample 57 with target label 0
# unsat for sample 57 with target label 1
# unsat for sample 57 with target label 2
# unsat for sample 57 with target label 3
# unsat for sample 57 with target label 4
# unsat for sample 57 with target label 5
# unsat for sample 57 with target label 6
# unsat for sample 57 with target label 7
# unsat for sample 57 with target label 8
# unsat for sample 58 with target label 0
# unsat for sample 58 with target label 1
# unsat for sample 58 with target label 2
# unsat for sample 58 with target label 3
# unsat for sample 58 with target label 5
# unsat for sample 58 with target label 6
# unsat for sample 58 with target label 7
# unsat for sample 58 with target label 8
# unsat for sample 58 with target label 9
# unsat for sample 59 with target label 0
# unsat for sample 59 with target label 2
# unsat for sample 59 with target label 3
# unsat for sample 59 with target label 4
# unsat for sample 59 with target label 5
# unsat for sample 59 with target label 6
# unsat for sample 59 with target label 7
# unsat for sample 59 with target label 8
# unsat for sample 59 with target label 9
# unsat for sample 60 with target label 0
# unsat for sample 60 with target label 1
# unsat for sample 60 with target label 2
# unsat for sample 60 with target label 3
# unsat for sample 60 with target label 5
# unsat for sample 60 with target label 6
# unsat for sample 60 with target label 7
# unsat for sample 60 with target label 8
# unsat for sample 60 with target label 9
# unsat for sample 61 with target label 0
# unsat for sample 61 with target label 1
# unsat for sample 61 with target label 2
# unsat for sample 61 with target label 3
# unsat for sample 61 with target label 5
# unsat for sample 61 with target label 6
# unsat for sample 61 with target label 7
# unsat for sample 61 with target label 8
# unsat for sample 61 with target label 9
# unsat for sample 62 with target label 0
# unsat for sample 62 with target label 1
# unsat for sample 62 with target label 2
# unsat for sample 62 with target label 3
# unsat for sample 62 with target label 4
# unsat for sample 62 with target label 5
# unsat for sample 62 with target label 7
# unsat for sample 62 with target label 8
# unsat for sample 62 with target label 9
# unsat for sample 63 with target label 1
# unsat for sample 63 with target label 2
# unsat for sample 63 with target label 3
# unsat for sample 63 with target label 4
# unsat for sample 63 with target label 5
# unsat for sample 63 with target label 6
# unsat for sample 63 with target label 7
# unsat for sample 63 with target label 8
# unsat for sample 63 with target label 9
# unsat for sample 64 with target label 0
# unsat for sample 64 with target label 1
# unsat for sample 64 with target label 2
# unsat for sample 64 with target label 3
# unsat for sample 64 with target label 5
# unsat for sample 64 with target label 6
# unsat for sample 64 with target label 7
# unsat for sample 64 with target label 8
# unsat for sample 64 with target label 9
# unsat for sample 65 with target label 0
# unsat for sample 65 with target label 1
# unsat for sample 65 with target label 2
# unsat for sample 65 with target label 3
# unsat for sample 65 with target label 4
# unsat for sample 65 with target label 6
# unsat for sample 65 with target label 7
# unsat for sample 65 with target label 8
# unsat for sample 65 with target label 9
# unsat for sample 66 with target label 0
# unsat for sample 66 with target label 1
# unsat for sample 66 with target label 2
# unsat for sample 66 with target label 3
# unsat for sample 66 with target label 4
# unsat for sample 66 with target label 5
# unsat for sample 66 with target label 7
# unsat for sample 66 with target label 8
# unsat for sample 66 with target label 9
# unsat for sample 67 with target label 0
# unsat for sample 67 with target label 2
# unsat for sample 67 with target label 3
# unsat for sample 67 with target label 4
# unsat for sample 67 with target label 5
# unsat for sample 67 with target label 6
# unsat for sample 67 with target label 7
# unsat for sample 67 with target label 8
# unsat for sample 67 with target label 9
# unsat for sample 68 with target label 1
# sat for sample 68 with target label 2
# adv data shape (12, 784) (12,)
# num sat samples: 12, num unsat samples: 602
# unsat for sample 68 with target label 3
# unsat for sample 68 with target label 4
# unsat for sample 68 with target label 5
# unsat for sample 68 with target label 6
# unsat for sample 68 with target label 7
# unsat for sample 68 with target label 8
# unsat for sample 68 with target label 9
# unsat for sample 69 with target label 1
# unsat for sample 69 with target label 2
# unsat for sample 69 with target label 3
# unsat for sample 69 with target label 4
# unsat for sample 69 with target label 5
# unsat for sample 69 with target label 6
# unsat for sample 69 with target label 7
# unsat for sample 69 with target label 8
# unsat for sample 69 with target label 9
# unsat for sample 70 with target label 0
# unsat for sample 70 with target label 2
# unsat for sample 70 with target label 3
# unsat for sample 70 with target label 4
# unsat for sample 70 with target label 5
# unsat for sample 70 with target label 6
# unsat for sample 70 with target label 7
# unsat for sample 70 with target label 8
# unsat for sample 70 with target label 9
# unsat for sample 71 with target label 0
# unsat for sample 71 with target label 1
# unsat for sample 71 with target label 2
# unsat for sample 71 with target label 3
# unsat for sample 71 with target label 4
# unsat for sample 71 with target label 5
# unsat for sample 71 with target label 6
# unsat for sample 71 with target label 8
# unsat for sample 71 with target label 9
# unsat for sample 72 with target label 0
# unsat for sample 72 with target label 2
# unsat for sample 72 with target label 3
# unsat for sample 72 with target label 4
# unsat for sample 72 with target label 5
# unsat for sample 72 with target label 6
# unsat for sample 72 with target label 7
# unsat for sample 72 with target label 8
# unsat for sample 72 with target label 9
# unsat for sample 73 with target label 0
# unsat for sample 73 with target label 1
# unsat for sample 73 with target label 2
# unsat for sample 73 with target label 3
# unsat for sample 73 with target label 4
# unsat for sample 73 with target label 5
# unsat for sample 73 with target label 7
# unsat for sample 73 with target label 8
# unsat for sample 73 with target label 9
# unsat for sample 74 with target label 0
# unsat for sample 74 with target label 1
# unsat for sample 74 with target label 2
# unsat for sample 74 with target label 4
# unsat for sample 74 with target label 5
# unsat for sample 74 with target label 6
# unsat for sample 74 with target label 7
# unsat for sample 74 with target label 8
# unsat for sample 74 with target label 9
# unsat for sample 75 with target label 1
# unsat for sample 75 with target label 2
# unsat for sample 75 with target label 3
# unsat for sample 75 with target label 4
# unsat for sample 75 with target label 5
# unsat for sample 75 with target label 6
# unsat for sample 75 with target label 7
# unsat for sample 75 with target label 8
# unsat for sample 75 with target label 9
# unsat for sample 76 with target label 0
# unsat for sample 76 with target label 1
# unsat for sample 76 with target label 3
# unsat for sample 76 with target label 4
# unsat for sample 76 with target label 5
# unsat for sample 76 with target label 6
# unsat for sample 76 with target label 7
# unsat for sample 76 with target label 8
# unsat for sample 76 with target label 9
# unsat for sample 77 with target label 0
# unsat for sample 77 with target label 2
# unsat for sample 77 with target label 3
# unsat for sample 77 with target label 4
# unsat for sample 77 with target label 5
# unsat for sample 77 with target label 6
# unsat for sample 77 with target label 7
# unsat for sample 77 with target label 8
# unsat for sample 77 with target label 9
# unsat for sample 78 with target label 0
# unsat for sample 78 with target label 2
# unsat for sample 78 with target label 3
# unsat for sample 78 with target label 4
# unsat for sample 78 with target label 5
# unsat for sample 78 with target label 6
# unsat for sample 78 with target label 7
# unsat for sample 78 with target label 8
# unsat for sample 78 with target label 9
# unsat for sample 79 with target label 0
# unsat for sample 79 with target label 1
# unsat for sample 79 with target label 2
# unsat for sample 79 with target label 3
# unsat for sample 79 with target label 4
# unsat for sample 79 with target label 5
# unsat for sample 79 with target label 6
# unsat for sample 79 with target label 8
# unsat for sample 79 with target label 9
# sat for sample 80 with target label 0
# adv data shape (13, 784) (13,)
# num sat samples: 13, num unsat samples: 708
# unsat for sample 80 with target label 1
# unsat for sample 80 with target label 2
# unsat for sample 80 with target label 3
# unsat for sample 80 with target label 4
# unsat for sample 80 with target label 5
# unsat for sample 80 with target label 6
# unsat for sample 80 with target label 7
# sat for sample 80 with target label 8
# adv data shape (14, 784) (14,)
# num sat samples: 14, num unsat samples: 715
# unsat for sample 81 with target label 1
# unsat for sample 81 with target label 2
# unsat for sample 81 with target label 3
# unsat for sample 81 with target label 4
# unsat for sample 81 with target label 5
# unsat for sample 81 with target label 6
# unsat for sample 81 with target label 7
# unsat for sample 81 with target label 8
# unsat for sample 81 with target label 9
# unsat for sample 82 with target label 0
# unsat for sample 82 with target label 1
# unsat for sample 82 with target label 3
# unsat for sample 82 with target label 4
# unsat for sample 82 with target label 5
# unsat for sample 82 with target label 6
# unsat for sample 82 with target label 7
# unsat for sample 82 with target label 8
# unsat for sample 82 with target label 9
# unsat for sample 83 with target label 0
# unsat for sample 83 with target label 1
# unsat for sample 83 with target label 2
# unsat for sample 83 with target label 3
# unsat for sample 83 with target label 4
# unsat for sample 83 with target label 5
# unsat for sample 83 with target label 7
# unsat for sample 83 with target label 8
# unsat for sample 83 with target label 9
# unsat for sample 84 with target label 0
# unsat for sample 84 with target label 1
# unsat for sample 84 with target label 2
# unsat for sample 84 with target label 3
# unsat for sample 84 with target label 4
# unsat for sample 84 with target label 5
# unsat for sample 84 with target label 6
# unsat for sample 84 with target label 8
# unsat for sample 84 with target label 9
# unsat for sample 85 with target label 0
# unsat for sample 85 with target label 1
# unsat for sample 85 with target label 2
# unsat for sample 85 with target label 3
# unsat for sample 85 with target label 4
# unsat for sample 85 with target label 5
# unsat for sample 85 with target label 6
# unsat for sample 85 with target label 7
# unsat for sample 85 with target label 9
# unsat for sample 86 with target label 0
# unsat for sample 86 with target label 1
# unsat for sample 86 with target label 2
# unsat for sample 86 with target label 4
# unsat for sample 86 with target label 5
# unsat for sample 86 with target label 6
# unsat for sample 86 with target label 7
# unsat for sample 86 with target label 8
# unsat for sample 86 with target label 9
# unsat for sample 87 with target label 0
# unsat for sample 87 with target label 1
# unsat for sample 87 with target label 2
# unsat for sample 87 with target label 3
# unsat for sample 87 with target label 4
# unsat for sample 87 with target label 5
# unsat for sample 87 with target label 6
# unsat for sample 87 with target label 7
# unsat for sample 87 with target label 8
# unsat for sample 88 with target label 1
# unsat for sample 88 with target label 2
# unsat for sample 88 with target label 3
# unsat for sample 88 with target label 4
# unsat for sample 88 with target label 5
# unsat for sample 88 with target label 6
# unsat for sample 88 with target label 7
# unsat for sample 88 with target label 8
# unsat for sample 88 with target label 9
# unsat for sample 89 with target label 0
# unsat for sample 89 with target label 1
# unsat for sample 89 with target label 2
# unsat for sample 89 with target label 3
# unsat for sample 89 with target label 5
# unsat for sample 89 with target label 6
# unsat for sample 89 with target label 7
# unsat for sample 89 with target label 8
# unsat for sample 89 with target label 9
# unsat for sample 90 with target label 0
# unsat for sample 90 with target label 1
# unsat for sample 90 with target label 2
# unsat for sample 90 with target label 3
# unsat for sample 90 with target label 4
# unsat for sample 90 with target label 5
# unsat for sample 90 with target label 7
# unsat for sample 90 with target label 8
# unsat for sample 90 with target label 9
# unsat for sample 91 with target label 0
# unsat for sample 91 with target label 1
# unsat for sample 91 with target label 2
# unsat for sample 91 with target label 3
# unsat for sample 91 with target label 4
# unsat for sample 91 with target label 5
# unsat for sample 91 with target label 6
# unsat for sample 91 with target label 8
# unsat for sample 91 with target label 9
# unsat for sample 92 with target label 0
# unsat for sample 92 with target label 1
# unsat for sample 92 with target label 2
# unsat for sample 92 with target label 3
# unsat for sample 92 with target label 5
# unsat for sample 92 with target label 6
# unsat for sample 92 with target label 7
# unsat for sample 92 with target label 8
# unsat for sample 92 with target label 9
# unsat for sample 93 with target label 0
# unsat for sample 93 with target label 1
# unsat for sample 93 with target label 2
# unsat for sample 93 with target label 3
# unsat for sample 93 with target label 4
# unsat for sample 93 with target label 5
# unsat for sample 93 with target label 7
# unsat for sample 93 with target label 8
# unsat for sample 93 with target label 9
# unsat for sample 94 with target label 0
# unsat for sample 94 with target label 1
# unsat for sample 94 with target label 2
# unsat for sample 94 with target label 3
# unsat for sample 94 with target label 4
# unsat for sample 94 with target label 5
# unsat for sample 94 with target label 6
# unsat for sample 94 with target label 7
# unsat for sample 94 with target label 9
# unsat for sample 95 with target label 1
# unsat for sample 95 with target label 2
# unsat for sample 95 with target label 3
# unsat for sample 95 with target label 4
# unsat for sample 95 with target label 5
# unsat for sample 95 with target label 6
# unsat for sample 95 with target label 7
# unsat for sample 95 with target label 8
# unsat for sample 95 with target label 9
# unsat for sample 96 with target label 0
# unsat for sample 96 with target label 1
# unsat for sample 96 with target label 2
# unsat for sample 96 with target label 3
# unsat for sample 96 with target label 4
# unsat for sample 96 with target label 5
# unsat for sample 96 with target label 6
# unsat for sample 96 with target label 8
# unsat for sample 96 with target label 9
# unsat for sample 97 with target label 0
# unsat for sample 97 with target label 1
# unsat for sample 97 with target label 2
# unsat for sample 97 with target label 3
# unsat for sample 97 with target label 4
# unsat for sample 97 with target label 5
# unsat for sample 97 with target label 6
# unsat for sample 97 with target label 7
# unsat for sample 97 with target label 9
# unsat for sample 98 with target label 0
# unsat for sample 98 with target label 1
# unsat for sample 98 with target label 2
# unsat for sample 98 with target label 4
# unsat for sample 98 with target label 5
# unsat for sample 98 with target label 6
# unsat for sample 98 with target label 7
# unsat for sample 98 with target label 8
# unsat for sample 98 with target label 9
# unsat for sample 99 with target label 0
# unsat for sample 99 with target label 2
# unsat for sample 99 with target label 3
# unsat for sample 99 with target label 4
# unsat for sample 99 with target label 5
# unsat for sample 99 with target label 6
# unsat for sample 99 with target label 7
# unsat for sample 99 with target label 8
# unsat for sample 99 with target label 9
# unsat for sample 100 with target label 0
# unsat for sample 100 with target label 1
# unsat for sample 100 with target label 2
# unsat for sample 100 with target label 3
# unsat for sample 100 with target label 4
# unsat for sample 100 with target label 6
# unsat for sample 100 with target label 7
# unsat for sample 100 with target label 8
# unsat for sample 100 with target label 9
# unsat for sample 101 with target label 0
# unsat for sample 101 with target label 1
# unsat for sample 101 with target label 2
# unsat for sample 101 with target label 3
# unsat for sample 101 with target label 4
# unsat for sample 101 with target label 5
# unsat for sample 101 with target label 6
# unsat for sample 101 with target label 8
# unsat for sample 101 with target label 9
# unsat for sample 102 with target label 0
# unsat for sample 102 with target label 2
# unsat for sample 102 with target label 3
# unsat for sample 102 with target label 4
# unsat for sample 102 with target label 5
# unsat for sample 102 with target label 6
# unsat for sample 102 with target label 7
# unsat for sample 102 with target label 8
# unsat for sample 102 with target label 9
# unsat for sample 103 with target label 0
# unsat for sample 103 with target label 1
# unsat for sample 103 with target label 2
# unsat for sample 103 with target label 3
# unsat for sample 103 with target label 4
# unsat for sample 103 with target label 5
# unsat for sample 103 with target label 6
# unsat for sample 103 with target label 8
# unsat for sample 103 with target label 9
# unsat for sample 104 with target label 0
# unsat for sample 104 with target label 2
# unsat for sample 104 with target label 3
# unsat for sample 104 with target label 4
# unsat for sample 104 with target label 5
# unsat for sample 104 with target label 6
# unsat for sample 104 with target label 7
# unsat for sample 104 with target label 8
# unsat for sample 104 with target label 9
# unsat for sample 105 with target label 0
# unsat for sample 105 with target label 2
# unsat for sample 105 with target label 3
# unsat for sample 105 with target label 4
# unsat for sample 105 with target label 5
# unsat for sample 105 with target label 6
# unsat for sample 105 with target label 7
# unsat for sample 105 with target label 8
# unsat for sample 105 with target label 9
# unsat for sample 106 with target label 0
# unsat for sample 106 with target label 1
# unsat for sample 106 with target label 2
# unsat for sample 106 with target label 3
# unsat for sample 106 with target label 4
# unsat for sample 106 with target label 5
# unsat for sample 106 with target label 7
# unsat for sample 106 with target label 8
# unsat for sample 106 with target label 9
# unsat for sample 107 with target label 0
# unsat for sample 107 with target label 1
# unsat for sample 107 with target label 2
# unsat for sample 107 with target label 4
# unsat for sample 107 with target label 5
# unsat for sample 107 with target label 6
# unsat for sample 107 with target label 7
# unsat for sample 107 with target label 8
# unsat for sample 107 with target label 9
# unsat for sample 108 with target label 1
# unsat for sample 108 with target label 2
# unsat for sample 108 with target label 3
# unsat for sample 108 with target label 4
# unsat for sample 108 with target label 5
# unsat for sample 108 with target label 6
# unsat for sample 108 with target label 7
# unsat for sample 108 with target label 8
# unsat for sample 108 with target label 9
# unsat for sample 109 with target label 0
# unsat for sample 109 with target label 1
# unsat for sample 109 with target label 3
# unsat for sample 109 with target label 4
# unsat for sample 109 with target label 5
# unsat for sample 109 with target label 6
# unsat for sample 109 with target label 7
# unsat for sample 109 with target label 8
# unsat for sample 109 with target label 9
# unsat for sample 110 with target label 0
# unsat for sample 110 with target label 1
# unsat for sample 110 with target label 2
# unsat for sample 110 with target label 3
# unsat for sample 110 with target label 4
# unsat for sample 110 with target label 5
# unsat for sample 110 with target label 6
# unsat for sample 110 with target label 7
# unsat for sample 110 with target label 8
# unsat for sample 111 with target label 0
# unsat for sample 111 with target label 1
# unsat for sample 111 with target label 2
# unsat for sample 111 with target label 4
# unsat for sample 111 with target label 5
# unsat for sample 111 with target label 6
# unsat for sample 111 with target label 7
# unsat for sample 111 with target label 8
# unsat for sample 111 with target label 9
# unsat for sample 112 with target label 0
# unsat for sample 112 with target label 2
# unsat for sample 112 with target label 3
# unsat for sample 112 with target label 4
# unsat for sample 112 with target label 5
# unsat for sample 112 with target label 6
# unsat for sample 112 with target label 7
# unsat for sample 112 with target label 8
# unsat for sample 112 with target label 9
# unsat for sample 113 with target label 0
# unsat for sample 113 with target label 2
# unsat for sample 113 with target label 3
# unsat for sample 113 with target label 4
# unsat for sample 113 with target label 5
# unsat for sample 113 with target label 6
# unsat for sample 113 with target label 7
# unsat for sample 113 with target label 8
# unsat for sample 113 with target label 9
# unsat for sample 114 with target label 1
# unsat for sample 114 with target label 2
# unsat for sample 114 with target label 3
# unsat for sample 114 with target label 4
# unsat for sample 114 with target label 5
# unsat for sample 114 with target label 6
# unsat for sample 114 with target label 7
# unsat for sample 114 with target label 8
# unsat for sample 114 with target label 9
# unsat for sample 115 with target label 0
# unsat for sample 115 with target label 1
# unsat for sample 115 with target label 2
# unsat for sample 115 with target label 3
# unsat for sample 115 with target label 5
# unsat for sample 115 with target label 6
# unsat for sample 115 with target label 7
# unsat for sample 115 with target label 8
# unsat for sample 115 with target label 9
# unsat for sample 116 with target label 0
# unsat for sample 116 with target label 1
# unsat for sample 116 with target label 2
# unsat for sample 116 with target label 3
# unsat for sample 116 with target label 4
# unsat for sample 116 with target label 5
# unsat for sample 116 with target label 6
# unsat for sample 116 with target label 7
# unsat for sample 116 with target label 8
# unsat for sample 117 with target label 0
# unsat for sample 117 with target label 1
# unsat for sample 117 with target label 3
# unsat for sample 117 with target label 4
# unsat for sample 117 with target label 5
# unsat for sample 117 with target label 6
# unsat for sample 117 with target label 7
# unsat for sample 117 with target label 8
# unsat for sample 117 with target label 9
# unsat for sample 118 with target label 1
# unsat for sample 118 with target label 2
# unsat for sample 118 with target label 3
# unsat for sample 118 with target label 4
# unsat for sample 118 with target label 5
# unsat for sample 118 with target label 6
# unsat for sample 118 with target label 7
# unsat for sample 118 with target label 8
# unsat for sample 118 with target label 9
# unsat for sample 119 with target label 1
# unsat for sample 119 with target label 2
# unsat for sample 119 with target label 3
# unsat for sample 119 with target label 4
# unsat for sample 119 with target label 5
# unsat for sample 119 with target label 6
# unsat for sample 119 with target label 7
# unsat for sample 119 with target label 8
# unsat for sample 119 with target label 9
# unsat for sample 120 with target label 0
# unsat for sample 120 with target label 1
# unsat for sample 120 with target label 3
# unsat for sample 120 with target label 4
# unsat for sample 120 with target label 5
# unsat for sample 120 with target label 6
# sat for sample 120 with target label 7
# adv data shape (15, 784) (15,)
# num sat samples: 15, num unsat samples: 1072
# unsat for sample 120 with target label 8
# unsat for sample 120 with target label 9
# unsat for sample 121 with target label 1
# unsat for sample 121 with target label 2
# unsat for sample 121 with target label 3
# unsat for sample 121 with target label 4
# unsat for sample 121 with target label 5
# unsat for sample 121 with target label 6
# unsat for sample 121 with target label 7
# unsat for sample 121 with target label 8
# unsat for sample 121 with target label 9
# unsat for sample 122 with target label 0
# unsat for sample 122 with target label 1
# unsat for sample 122 with target label 3
# unsat for sample 122 with target label 4
# unsat for sample 122 with target label 5
# unsat for sample 122 with target label 6
# unsat for sample 122 with target label 7
# unsat for sample 122 with target label 8
# unsat for sample 122 with target label 9
# unsat for sample 123 with target label 0
# unsat for sample 123 with target label 1
# unsat for sample 123 with target label 2
# unsat for sample 123 with target label 3
# unsat for sample 123 with target label 4
# unsat for sample 123 with target label 5
# unsat for sample 123 with target label 6
# unsat for sample 123 with target label 8
# unsat for sample 123 with target label 9
# unsat for sample 124 with target label 0
# unsat for sample 124 with target label 2
# unsat for sample 124 with target label 3
# unsat for sample 124 with target label 4
# unsat for sample 124 with target label 5
# unsat for sample 124 with target label 6
# unsat for sample 124 with target label 7
# unsat for sample 124 with target label 8
# unsat for sample 124 with target label 9
# unsat for sample 125 with target label 0
# unsat for sample 125 with target label 1
# unsat for sample 125 with target label 2
# unsat for sample 125 with target label 3
# unsat for sample 125 with target label 4
# unsat for sample 125 with target label 5
# unsat for sample 125 with target label 6
# unsat for sample 125 with target label 7
# unsat for sample 125 with target label 9
# unsat for sample 126 with target label 0
# unsat for sample 126 with target label 1
# unsat for sample 126 with target label 2
# unsat for sample 126 with target label 3
# unsat for sample 126 with target label 4
# unsat for sample 126 with target label 5
# unsat for sample 126 with target label 7
# unsat for sample 126 with target label 8
# unsat for sample 126 with target label 9
# unsat for sample 127 with target label 0
# unsat for sample 127 with target label 1
# unsat for sample 127 with target label 2
# unsat for sample 127 with target label 3
# unsat for sample 127 with target label 5
# unsat for sample 127 with target label 6
# unsat for sample 127 with target label 7
# unsat for sample 127 with target label 8
# unsat for sample 127 with target label 9
# unsat for sample 128 with target label 0
# unsat for sample 128 with target label 2
# unsat for sample 128 with target label 3
# unsat for sample 128 with target label 4
# unsat for sample 128 with target label 5
# unsat for sample 128 with target label 6
# unsat for sample 128 with target label 7
# unsat for sample 128 with target label 8
# unsat for sample 128 with target label 9
# unsat for sample 129 with target label 0
# unsat for sample 129 with target label 1
# unsat for sample 129 with target label 2
# unsat for sample 129 with target label 3
# unsat for sample 129 with target label 4
# unsat for sample 129 with target label 5
# unsat for sample 129 with target label 7
# ...
# unsat for sample 458 with target label 8
# unsat for sample 458 with target label 9
# unsat for sample 459 with target label 0
# unsat for sample 459 with target label 1
# unsat for sample 459 with target label 2
# unsat for sample 459 with target label 4
# unsat for sample 459 with target label 5
# unsat for sample 459 with target label 6
# unsat for sample 459 with target label 7
# unsat for sample 459 with target label 8
# unsat for sample 459 with target label 9
# unsat for sample 460 with target label 0
# unsat for sample 460 with target label 1
# unsat for sample 460 with target label 2
# unsat for sample 460 with target label 3
# unsat for sample 460 with target label 4
# unsat for sample 460 with target label 5
# unsat for sample 460 with target label 6
# unsat for sample 460 with target label 7
# unsat for sample 460 with target label 8
# unsat for sample 461 with target label 0
# unsat for sample 461 with target label 1
# unsat for sample 461 with target label 2
# unsat for sample 461 with target label 3
# unsat for sample 461 with target label 5
# unsat for sample 461 with target label 6
# unsat for sample 461 with target label 7
# unsat for sample 461 with target label 8
# unsat for sample 461 with target label 9
# unsat for sample 462 with target label 1
# unsat for sample 462 with target label 2
# unsat for sample 462 with target label 3
# unsat for sample 462 with target label 4
# unsat for sample 462 with target label 5
# unsat for sample 462 with target label 6
# unsat for sample 462 with target label 7
# unsat for sample 462 with target label 8
# unsat for sample 462 with target label 9
# unsat for sample 463 with target label 0
# unsat for sample 463 with target label 1
# unsat for sample 463 with target label 2
# unsat for sample 463 with target label 3
# unsat for sample 463 with target label 4
# unsat for sample 463 with target label 6
# unsat for sample 463 with target label 7
# unsat for sample 463 with target label 8
# unsat for sample 463 with target label 9
# unsat for sample 464 with target label 1
# unsat for sample 464 with target label 2
# unsat for sample 464 with target label 3
# unsat for sample 464 with target label 4
# unsat for sample 464 with target label 5
# unsat for sample 464 with target label 6
# unsat for sample 464 with target label 7
# unsat for sample 464 with target label 8
# unsat for sample 464 with target label 9
# unsat for sample 465 with target label 0
# unsat for sample 465 with target label 1
# unsat for sample 465 with target label 2
# unsat for sample 465 with target label 3
# unsat for sample 465 with target label 4
# unsat for sample 465 with target label 5
# unsat for sample 465 with target label 7
# unsat for sample 465 with target label 8
# unsat for sample 465 with target label 9
# unsat for sample 466 with target label 0
# unsat for sample 466 with target label 2
# unsat for sample 466 with target label 3
# unsat for sample 466 with target label 4
# unsat for sample 466 with target label 5
# unsat for sample 466 with target label 6
# unsat for sample 466 with target label 7
# unsat for sample 466 with target label 8
# unsat for sample 466 with target label 9
# unsat for sample 467 with target label 0
# unsat for sample 467 with target label 1
# unsat for sample 467 with target label 2
# unsat for sample 467 with target label 3
# unsat for sample 467 with target label 4
# unsat for sample 467 with target label 5
# unsat for sample 467 with target label 6
# unsat for sample 467 with target label 8
# unsat for sample 467 with target label 9
# unsat for sample 468 with target label 0
# unsat for sample 468 with target label 1
# unsat for sample 468 with target label 2
# unsat for sample 468 with target label 3
# unsat for sample 468 with target label 4
# unsat for sample 468 with target label 5
# unsat for sample 468 with target label 6
# unsat for sample 468 with target label 8
# unsat for sample 468 with target label 9
# unsat for sample 469 with target label 0
# unsat for sample 469 with target label 1
# unsat for sample 469 with target label 2
# unsat for sample 469 with target label 3
# unsat for sample 469 with target label 4
# unsat for sample 469 with target label 5
# unsat for sample 469 with target label 6
# unsat for sample 469 with target label 7
# unsat for sample 469 with target label 9
# unsat for sample 470 with target label 0
# unsat for sample 470 with target label 2
# unsat for sample 470 with target label 3
# unsat for sample 470 with target label 4
# sat for sample 470 with target label 5
# adv data shape (95, 784) (95,)
# num sat samples: 95, num unsat samples: 4140
# sat for sample 470 with target label 6
# adv data shape (96, 784) (96,)
# num sat samples: 96, num unsat samples: 4140
# unsat for sample 470 with target label 7
# sat for sample 470 with target label 8
# adv data shape (97, 784) (97,)
# num sat samples: 97, num unsat samples: 4141
# unsat for sample 470 with target label 9
# unsat for sample 471 with target label 0
# unsat for sample 471 with target label 1
# unsat for sample 471 with target label 2
# unsat for sample 471 with target label 3
# unsat for sample 471 with target label 4
# unsat for sample 471 with target label 5
# unsat for sample 471 with target label 6
# unsat for sample 471 with target label 7
# unsat for sample 471 with target label 8
# unsat for sample 472 with target label 0
# sat for sample 472 with target label 1
# adv data shape (98, 784) (98,)
# num sat samples: 98, num unsat samples: 4152
# unsat for sample 472 with target label 3
# unsat for sample 472 with target label 4
# unsat for sample 472 with target label 5
# unsat for sample 472 with target label 6
# unsat for sample 472 with target label 7
# unsat for sample 472 with target label 8
# unsat for sample 472 with target label 9
# unsat for sample 473 with target label 1
# unsat for sample 473 with target label 2
# unsat for sample 473 with target label 3
# unsat for sample 473 with target label 4
# unsat for sample 473 with target label 5
# unsat for sample 473 with target label 6
# unsat for sample 473 with target label 7
# unsat for sample 473 with target label 8
# unsat for sample 473 with target label 9
# unsat for sample 474 with target label 0
# unsat for sample 474 with target label 1
# unsat for sample 474 with target label 2
# unsat for sample 474 with target label 3
# unsat for sample 474 with target label 4
# unsat for sample 474 with target label 6
# unsat for sample 474 with target label 7
# unsat for sample 474 with target label 8
# unsat for sample 474 with target label 9
# unsat for sample 475 with target label 0
# unsat for sample 475 with target label 2
# unsat for sample 475 with target label 3
# unsat for sample 475 with target label 4
# unsat for sample 475 with target label 5
# unsat for sample 475 with target label 6
# unsat for sample 475 with target label 7
# unsat for sample 475 with target label 8
# unsat for sample 475 with target label 9
# unsat for sample 476 with target label 0
# unsat for sample 476 with target label 1
# unsat for sample 476 with target label 3
# unsat for sample 476 with target label 4
# unsat for sample 476 with target label 5
# unsat for sample 476 with target label 6
# unsat for sample 476 with target label 7
# unsat for sample 476 with target label 8
# unsat for sample 476 with target label 9
# unsat for sample 477 with target label 0
# unsat for sample 477 with target label 1
# unsat for sample 477 with target label 3
# unsat for sample 477 with target label 4
# unsat for sample 477 with target label 5
# unsat for sample 477 with target label 6
# unsat for sample 477 with target label 7
# unsat for sample 477 with target label 8
# unsat for sample 477 with target label 9
# unsat for sample 478 with target label 0
# unsat for sample 478 with target label 1
# unsat for sample 478 with target label 2
# unsat for sample 478 with target label 3
# unsat for sample 478 with target label 4
# unsat for sample 478 with target label 5
# unsat for sample 478 with target label 6
# unsat for sample 478 with target label 8
# unsat for sample 478 with target label 9
# unsat for sample 479 with target label 0
# unsat for sample 479 with target label 1
# unsat for sample 479 with target label 2
# unsat for sample 479 with target label 4
# unsat for sample 479 with target label 5
# unsat for sample 479 with target label 6
# unsat for sample 479 with target label 7
# unsat for sample 479 with target label 8
# unsat for sample 479 with target label 9
# unsat for sample 480 with target label 0
# unsat for sample 480 with target label 1
# unsat for sample 480 with target label 2
# unsat for sample 480 with target label 3
# unsat for sample 480 with target label 4
# unsat for sample 480 with target label 6
# unsat for sample 480 with target label 7
# sat for sample 480 with target label 8
# adv data shape (99, 784) (99,)
# num sat samples: 99, num unsat samples: 4229
# unsat for sample 480 with target label 9
# unsat for sample 481 with target label 0
# unsat for sample 481 with target label 1
# unsat for sample 481 with target label 2
# unsat for sample 481 with target label 3
# unsat for sample 481 with target label 5
# unsat for sample 481 with target label 6
# unsat for sample 481 with target label 7
# unsat for sample 481 with target label 8
# unsat for sample 481 with target label 9
# unsat for sample 482 with target label 0
# unsat for sample 482 with target label 1
# unsat for sample 482 with target label 2
# unsat for sample 482 with target label 3
# sat for sample 482 with target label 4
# adv data shape (100, 784) (100,)
# num sat samples: 100, num unsat samples: 4243
# unsat for sample 482 with target label 5
# unsat for sample 482 with target label 6
# unsat for sample 482 with target label 7
# unsat for sample 482 with target label 8
# unsat for sample 483 with target label 0
# unsat for sample 483 with target label 1
# unsat for sample 483 with target label 2
# unsat for sample 483 with target label 3
# unsat for sample 483 with target label 4
# unsat for sample 483 with target label 5
# unsat for sample 483 with target label 6
# unsat for sample 483 with target label 8
# unsat for sample 483 with target label 9
# unsat for sample 484 with target label 0
# unsat for sample 484 with target label 2
# unsat for sample 484 with target label 3
# unsat for sample 484 with target label 4
# unsat for sample 484 with target label 5
# unsat for sample 484 with target label 6
# unsat for sample 484 with target label 7
# unsat for sample 484 with target label 8
# unsat for sample 484 with target label 9
# unsat for sample 485 with target label 0
# unsat for sample 485 with target label 1
# unsat for sample 485 with target label 2
# unsat for sample 485 with target label 3
# unsat for sample 485 with target label 4
# unsat for sample 485 with target label 5
# unsat for sample 485 with target label 6
# unsat for sample 485 with target label 7
# unsat for sample 485 with target label 9
# unsat for sample 486 with target label 0
# unsat for sample 486 with target label 1
# unsat for sample 486 with target label 2
# unsat for sample 486 with target label 4
# unsat for sample 486 with target label 5
# unsat for sample 486 with target label 6
# unsat for sample 486 with target label 7
# unsat for sample 486 with target label 8
# unsat for sample 486 with target label 9
# unsat for sample 487 with target label 0
# unsat for sample 487 with target label 1
# unsat for sample 487 with target label 2
# unsat for sample 487 with target label 3
# unsat for sample 487 with target label 4
# unsat for sample 487 with target label 5
# unsat for sample 487 with target label 6
# unsat for sample 487 with target label 7
# unsat for sample 487 with target label 8
# unsat for sample 488 with target label 0
# unsat for sample 488 with target label 1
# sat for sample 488 with target label 2
# adv data shape (101, 784) (101,)
# num sat samples: 101, num unsat samples: 4294
# unsat for sample 488 with target label 3
# sat for sample 488 with target label 4
# adv data shape (102, 784) (102,)
# num sat samples: 102, num unsat samples: 4295
# unsat for sample 488 with target label 5
# unsat for sample 488 with target label 7
# sat for sample 488 with target label 8
# adv data shape (103, 784) (103,)
# num sat samples: 103, num unsat samples: 4297
# unsat for sample 488 with target label 9
# unsat for sample 489 with target label 1
# unsat for sample 489 with target label 2
# unsat for sample 489 with target label 3
# unsat for sample 489 with target label 4
# unsat for sample 489 with target label 5
# unsat for sample 489 with target label 6
# unsat for sample 489 with target label 7
# unsat for sample 489 with target label 8
# unsat for sample 489 with target label 9
# unsat for sample 490 with target label 0
# unsat for sample 490 with target label 1
# unsat for sample 490 with target label 2
# unsat for sample 490 with target label 4
# unsat for sample 490 with target label 5
# unsat for sample 490 with target label 6
# unsat for sample 490 with target label 7
# unsat for sample 490 with target label 8
# unsat for sample 490 with target label 9
# unsat for sample 491 with target label 0
# unsat for sample 491 with target label 2
# unsat for sample 491 with target label 3
# unsat for sample 491 with target label 4
# unsat for sample 491 with target label 5
# unsat for sample 491 with target label 6
# unsat for sample 491 with target label 7
# unsat for sample 491 with target label 8
# unsat for sample 491 with target label 9
# unsat for sample 492 with target label 0
# unsat for sample 492 with target label 2
# unsat for sample 492 with target label 3
# unsat for sample 492 with target label 4
# unsat for sample 492 with target label 5
# unsat for sample 492 with target label 6
# unsat for sample 492 with target label 7
# unsat for sample 492 with target label 8
# unsat for sample 492 with target label 9
# unsat for sample 493 with target label 0
# unsat for sample 493 with target label 1
# unsat for sample 493 with target label 3
# unsat for sample 493 with target label 4
# unsat for sample 493 with target label 5
# unsat for sample 493 with target label 6
# unsat for sample 493 with target label 7
# unsat for sample 493 with target label 8
# unsat for sample 493 with target label 9
# sat for sample 494 with target label 0
# adv data shape (104, 784) (104,)
# num sat samples: 104, num unsat samples: 4343
# unsat for sample 494 with target label 1
# unsat for sample 494 with target label 2
# unsat for sample 494 with target label 3
# unsat for sample 494 with target label 4
# unsat for sample 494 with target label 5
# unsat for sample 494 with target label 7
# unsat for sample 494 with target label 8
# unsat for sample 494 with target label 9
# unsat for sample 495 with target label 0
# unsat for sample 495 with target label 1
# unsat for sample 495 with target label 2
# unsat for sample 495 with target label 4
# unsat for sample 495 with target label 5
# unsat for sample 495 with target label 6
# unsat for sample 495 with target label 7
# unsat for sample 495 with target label 8
# unsat for sample 495 with target label 9
# unsat for sample 496 with target label 0
# unsat for sample 496 with target label 1
# unsat for sample 496 with target label 2
# unsat for sample 496 with target label 3
# unsat for sample 496 with target label 4
# unsat for sample 496 with target label 6
# unsat for sample 496 with target label 7
# unsat for sample 496 with target label 8
# unsat for sample 496 with target label 9
# unsat for sample 497 with target label 0
# unsat for sample 497 with target label 1
# unsat for sample 497 with target label 2
# unsat for sample 497 with target label 3
# unsat for sample 497 with target label 4
# unsat for sample 497 with target label 5
# unsat for sample 497 with target label 6
# unsat for sample 497 with target label 8
# unsat for sample 497 with target label 9
# unsat for sample 498 with target label 0
# unsat for sample 498 with target label 1
# unsat for sample 498 with target label 2
# unsat for sample 498 with target label 3
# unsat for sample 498 with target label 4
# unsat for sample 498 with target label 5
# unsat for sample 498 with target label 7
# unsat for sample 498 with target label 8
# unsat for sample 498 with target label 9
# unsat for sample 499 with target label 0
# unsat for sample 499 with target label 1
# unsat for sample 499 with target label 2
# unsat for sample 499 with target label 3
# unsat for sample 499 with target label 4
# unsat for sample 499 with target label 5
# unsat for sample 499 with target label 6
# unsat for sample 499 with target label 7
# unsat for sample 499 with target label 9
# end time 12:59:36
